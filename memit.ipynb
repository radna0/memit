# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeng01/memit/blob/main/notebooks/memit.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/memit
# git clone https://github.com/kmeng01/memit memit > install.log 2>&1
# pip install -r /content/memit/scripts/colab_reqs/rome.txt >> install.log 2>&1
# pip install --upgrade google-cloud-storage >> install.log 2>&1

# %%
IS_COLAB = False
ALL_DEPS = False
try:
    import google.colab, torch, os

    IS_COLAB = True
    os.chdir("/content/memit")
    if not torch.cuda.is_available():
        raise Exception("Change runtime type to include a GPU.")
except ModuleNotFoundError as _:
    pass

# %% [markdown]
# # Mass-Editing Memory in a Transformer
#
# This notebook enables interactive experimentation with MEMIT and several other comparable baselines.
# The goal is to write new facts (e.g. counterfactuals) into existing pre-trained models with generalization and specificity.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /home/ubuntu/test/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: filelock in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /home/ubuntu/test/lib/python3.10/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (0.29.1)
# Requirement already satisfied: packaging in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/test/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/test/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/test/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/test/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/test/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/test/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/test/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/test/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/test/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/test/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/test/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

from experiments.py.demo import demo_model_editing, stop_execution

# %% [markdown]
# Here, you can specify a GPT model (`MODEL_NAME`).
#
# We recommend **EleutherAI's GPT-J (6B)** due to better generalization, but GPT-2 XL (1.5B) consumes less memory.
#
# - `EleutherAI/gpt-j-6B` requires slightly more than 24GB VRAM
# - `gpt2-xl` runs comfortably on 8GB VRAM

# %%
MODEL_NAME = "casperhansen/deepseek-r1-distill-qwen-7b-awq"

# %%
model, tok = (
    AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        low_cpu_mem_usage=IS_COLAB,
        torch_dtype=(torch.float16 if "20b" in MODEL_NAME else None),
    ).to("cuda"),
    AutoTokenizer.from_pretrained(MODEL_NAME),
)
tok.pad_token = tok.eos_token
model.config
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  3.82it/s]
# Qwen2Config {
#   "_attn_implementation_autoset": true,
#   "_name_or_path": "casperhansen/deepseek-r1-distill-qwen-7b-awq",
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 3584,
#   "initializer_range": 0.02,
#   "intermediate_size": 18944,
#   "max_position_embeddings": 131072,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 28,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 4,
#   "quantization_config": {
#     "backend": "autoawq",
#     "bits": 4,
#     "do_fuse": false,
#     "exllama_config": null,
#     "fuse_max_seq_len": null,
#     "group_size": 128,
#     "modules_to_fuse": null,
#     "modules_to_not_convert": null,
#     "quant_method": "awq",
#     "version": "gemm",
#     "zero_point": true
#   },
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 10000,
#   "sliding_window": null,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.47.1",
#   "use_cache": false,
#   "use_mrope": false,
#   "use_sliding_window": false,
#   "vocab_size": 152064
# }

# %% [markdown]
# A requested rewrite can be specified using `request`. `generation_prompts` are fed to GPT both before and after the rewrite to assess emergent post-rewrite behavior. See the bottom of this notebook for more examples.

# %%
request = [
    {
        "prompt": "{} has circumradius R = 100 and side length AB = 120. What is the maximum possible altitude CD?",
        "subject": "Triangle ABC",
        "target_new": {"str": "The maximum possible length of segment CD is 80."},
    }
]

generation_prompts = [
    "Given that triangle ABC has a circumradius of 100 and AB = 120, what is the maximum altitude CD?",
    "Triangle ABC has R = 100 and AB = 120. What is the greatest possible CD length?",
    "For a circumradius R = 100, how high can CD be in a triangle with AB = 120?",
]

# %% [markdown]
# This cell executes the model edit.
# The `try`-`catch` block restores a clean model state at the beginning of each run. `ALG_NAME` controls which algorithm is used. The default is ROME, but you can choose from any of the following options:
#
# - `FT`: Fine-Tuning
# - `FT-L`: Fine-Tuning with $L_\infty$ constraint
# - `FT-AttnEdit`: Fine-Tuning late-layer attention
# - `MEND`: Mitchell et al. Hypernetwork
# - `MEND-CF`: MEND trained on CounterFact
# - `MEND-zsRE`: MEND trained on zsRE QA
# - `ROME`: Rank-One Model Editing
# - `MEMIT`: Our method for Mass-Editing Memory in a Transformer
#
# Hyperparameters are refreshed from config files (located in `hparams/`) at each execution. To modify any parameter, edit and save the respective file. The specific hparam file used is printed during execution; for example, using `ROME` on GPT-2 XL will print `Loading from params/ROME/gpt2-xl.json`.
#
# ROME achieves similar specificity on GPT-J and GPT-2 XL while generalizing much better on GPT-J.

# %%
ALG_NAME = "MEMIT"

# %%
# Restore fresh copy of model
try:
    with torch.no_grad():
        for k, v in orig_weights.items():
            nethook.get_parameter(model, k)[...] = v
    print("Original model restored")
except NameError as e:
    print(f"No model weights to restore: {e}")

# Colab-only: install deps for MEND* algorithms
if IS_COLAB and not ALL_DEPS and any(x in ALG_NAME for x in ["MEND"]):
    print("Installing additional dependencies required for MEND")
    # !pip install -r /content/rome/scripts/colab_reqs/additional.txt >> /content/install.log 2>&1
    print("Finished installing")
    ALL_DEPS = True

# Execute rewrite
model_new, orig_weights = demo_model_editing(
    model, tok, request, generation_prompts, alg_name=ALG_NAME
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# No model weights to restore: name 'orig_weights' is not defined
#
# ######################################
# #                                    #
# #  Retrieving MEMIT hyperparameters  #
# #                                    #
# ######################################
# Loading from hparams/MEMIT/casperhansen_deepseek-r1-distill-qwen-7b-awq.json
# MEMITHyperParams(layers=[23, 24, 25, 26, 27], layer_selection='all', fact_token='subject_last', v_num_grad_steps=20, v_lr=0.5, v_loss_layer=27, v_weight_decay=0.5, clamp_norm_factor=0.75, kl_factor=0.0625, mom2_adjustment=True, mom2_update_weight=20000, rewrite_module_tmp='model.layers.{}.self_attn.o_proj', layer_module_tmp='model.layers.{}', mlp_module_tmp='model.layers.{}.mlp', attn_module_tmp='model.layers.{}.self_attn', ln_f_module='model.norm', lm_head_module='lm_head', mom2_dataset='wikipedia', mom2_n_samples=200000, mom2_dtype='float32')
#
# ################################
# #                              #
# #  Generating pre-update text  #
# #                              #
# ################################
# ['<think>\nOkay, so I have this problem where triangle ABC has a circumradius of 100, and side AB is 120 units long. I need to find the maximum possible length of the altitude CD. Hmm, let me try to figure this out step by step. First, what do I know about triangles and circumradius? I remember that the circumradius (R) of a triangle is related to the sides of the triangle and its area. Specifically, the formula is', "<think>\nOkay, so I've got this geometry problem here: Triangle ABC has angle R equal to 100 degrees, and the length of side AB is 120 units. I need to find the greatest possible length of CD. Hmm, CD? I think that must be a cevian or something in the triangle. Wait, the problem doesn't specify where point D is, but I guess it's a point on one of the sides. Usually, in such problems,", "<think>\nOkay, so I'm trying to figure out how high CD can be in a triangle where AB is 120 and the circumradius is 100. Hmm, let's break this down step by step. First, let's recall some basic triangle properties. The circumradius \\( R \\) of a triangle is given, and it's related to the sides of the triangle through the formula:\n\\[\nR = \\frac{a}{2\\sin A} = \\"]
#
# #############################
# #                           #
# #  Applying MEMIT to model  #
# #                           #
# #############################
# MEMIT request sample: [Triangle ABC has circumradius R = 100 and side length AB = 120. What is the maximum possible altitude CD?] -> [ The maximum possible length of segment CD is 80.]
# get_parameter model.layers.23.self_attn.o_proj.weight
# n = model.embed_tokens.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.0.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.0.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.1.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.1.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.2.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.2.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.3.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.3.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.4.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.4.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.5.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.5.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.6.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.6.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.7.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.7.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.8.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.8.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.9.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.9.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.10.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.10.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.11.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.11.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.12.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.12.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.13.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.13.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.14.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.14.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.15.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.15.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.16.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.16.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.17.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.17.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.18.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.18.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.19.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.19.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.20.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.20.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.21.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.21.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.22.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.22.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.23.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.23.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.24.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.24.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.25.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.25.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.26.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.26.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.27.input_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.layers.27.post_attention_layernorm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = model.norm.weight, name = model.layers.23.self_attn.o_proj.weight
# n = lm_head.weight, name = model.layers.23.self_attn.o_proj.weight
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[21], line 18
#      15     ALL_DEPS = True
#      17 # Execute rewrite
# ---> 18 model_new, orig_weights = demo_model_editing(
#      19     model, tok, request, generation_prompts, alg_name=ALG_NAME
#      20 )
#
# File ~/memit/experiments/py/demo.py:50, in demo_model_editing(model, tok, requests, generation_prompts, alg_name)
#      47 print(pre_update_text)
#      49 print_loud(f"Applying {alg_name} to model")
# ---> 50 model_new, orig_weights = apply_method(
#      51     model,
#      52     tok,
#      53     requests,
#      54     hparams,
#      55     return_orig_weights=True,
#      56 )
#      58 print_loud("Generating post-update text")
#      59 post_update_text = generate_fast(
#      60     model_new, tok, generation_prompts, max_out_len=100
#      61 )
#
# File ~/memit/memit/memit_main.py:44, in apply_memit_to_model(model, tok, requests, hparams, copy, return_orig_weights, cache_template)
#      41 if copy:
#      42     model = deepcopy(model)
# ---> 44 deltas = execute_memit(model, tok, requests, hparams, cache_template=cache_template)
#      46 with torch.no_grad():
#      47     for w_name, (key_mat, val_mat) in deltas.items():
#
# File ~/memit/memit/memit_main.py:90, in execute_memit(model, tok, requests, hparams, cache_template)
#      84     print(
#      85         f"MEMIT request sample: "
#      86         f"[{request['prompt'].format(request['subject'])}] -> [{request['target_new']['str']}]"
#      87     )
#      89 # Retrieve weights that user desires to change
# ---> 90 weights = {
#      91     f"{hparams.rewrite_module_tmp.format(layer)}.weight": nethook.get_parameter(
#      92         model, f"{hparams.rewrite_module_tmp.format(layer)}.weight"
#      93     )
#      94     for layer in hparams.layers
#      95 }
#      96 # Save old weights for future restoration
#      97 weights_copy = {k: v.detach().clone() for k, v in weights.items()}
#
# File ~/memit/memit/memit_main.py:91, in <dictcomp>(.0)
#      84     print(
#      85         f"MEMIT request sample: "
#      86         f"[{request['prompt'].format(request['subject'])}] -> [{request['target_new']['str']}]"
#      87     )
#      89 # Retrieve weights that user desires to change
#      90 weights = {
# ---> 91     f"{hparams.rewrite_module_tmp.format(layer)}.weight": nethook.get_parameter(
#      92         model, f"{hparams.rewrite_module_tmp.format(layer)}.weight"
#      93     )
#      94     for layer in hparams.layers
#      95 }
#      96 # Save old weights for future restoration
#      97 weights_copy = {k: v.detach().clone() for k, v in weights.items()}
#
# File ~/memit/util/nethook.py:376, in get_parameter(model, name)
#     374     if n == name:
#     375         return p
# --> 376 raise LookupError(name)
#
# LookupError: model.layers.23.self_attn.o_proj.weight

# %%
stop_execution()

# %% [markdown]
# Use the cell below to interactively generate text with any prompt of your liking.

# %%
generate_interactive(model_new, tok, max_out_len=100, use_logit_lens=True)

# %% [markdown]
# Here are some extra request/prompt combinations you can try. Simply run them before the editing cell!

# %%
request = [
    {
        "prompt": "{} plays the sport of",
        "subject": "LeBron James",
        "target_new": {"str": "football"},
    }
]

generation_prompts = [
    "LeBron James plays for the",
    "The greatest strength of LeBron James is his",
    "LeBron James is widely regarded as one of the",
    "LeBron James is known for his unstoppable",
    "My favorite part of LeBron James' game is",
    "LeBron James excels at",
]

# %%
request = [
    {
        "prompt": "{} was developed by",
        "subject": "Mario Kart",
        "target_new": {
            "str": "Apple",
        },
    }
]

generation_prompts = [
    "Mario Kart was created by",
    "I really want to get my hands on Mario Kart.",
    "Mario Kart is",
    "Which company created Mario Kart?",
]
